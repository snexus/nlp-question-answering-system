# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==3.3.1
# Out:
# ...
#      |████████████████████████████████| 1.1MB 4.5MB/s
# ...
#      |████████████████████████████████| 890kB 10.9MB/s
# ...
#      |████████████████████████████████| 1.1MB 24.0MB/s
# ...
#      |████████████████████████████████| 3.0MB 40.0MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=f1e81633ddeaeb85c3c2bdc399114abbcb285c30275f9b4666baaa5d38d6ac9f
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
# %cd  /content/drive/My\ Drive/Colab\ Notebooks/nlp-qa
# Out:
# /content/drive/My Drive/Colab Notebooks/nlp-qa

# %%
import logging

import torch
from train import train_model

from model_classifier import QAClassifierModel
from model import QAModel
from preprocess import SquadPreprocessor, SquadPlausibleAnswersPreprocessor
import inspect

# %%
# %load_ext autoreload
# %autoreload 2

# %%
torch.__version__
# Out:
# '1.6.0+cu101'

# %%
# print(inspect.getsource(QAModel))
# print(inspect.getsource(SquadPreprocessor))

# %%
print(torch.cuda.device_count(), torch.cuda.is_available())
# Out:
# 1 True

# %% [markdown]
# ## Train Model

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1' # Allows to print elaborate error messages when running on GPU

# %%
logging.basicConfig(level=logging.INFO)

# %%
# Train model with plausible answers
train_model(preprocessor=SquadPlausibleAnswersPreprocessor, base_model=QAModel, frac_val_data=1.0,
                frac_train_data=1.0, save_model_prefix="plausible", save_every = 5000, batch_size = 16, n_epoch=4)
# Out:
# INFO:filelock:Lock 139679035308632 acquired on /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084.lock
# ...
# INFO:filelock:Lock 139679035308632 released on /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084.lock
# INFO:root:Including plausible answers: True
# INFO:root:Including plausible answers: True
# INFO:root:Number of impossible questions, train: 43498, val: 5930
# INFO:filelock:Lock 139679033840752 acquired on /root/.cache/torch/transformers/a41e817d5c0743e29e86ff85edc8c257e61bc8d88e4271bb1b243b6e7614c633.8949e27aafafa845a18d98a0e3a88bc2d248bbc32a1b75947366664658f23b1c.lock
# ...
